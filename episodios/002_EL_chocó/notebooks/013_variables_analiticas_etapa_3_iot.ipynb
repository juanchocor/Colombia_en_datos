# %% [markdown]
# # Etapa 3
# Construcción reproducible; sin índice.

# %%
from pathlib import Path
import runpy
r=next(p for p in [Path.cwd(),*Path.cwd().parents] if (p/'scripts'/'construir_variables_etapa_3_iot.py').exists())
runpy.run_path(str(r/'scripts'/'construir_variables_etapa_3_iot.py'),run_name='__main__')
